# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/Tesi')

# %%
import cv2
import math
import copy
import random
import numpy as np
import pandas as pd
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from keras.models import load_model
from tensorflow.keras.utils import Sequence

import warnings
warnings.filterwarnings('ignore')

# %%
sequence_length = 4
sequence_stride = 2
batch_size      = 16

# %% [markdown]
# # Network model

# %% [markdown]
# ## Loading the pre-trained model

# %%
ed_path = 'models/wild/ED_wild_pre-trained.h5'
ed = load_model(ed_path)

ed.summary()

# %% [markdown]
# ## Remove the last layers

# %%
from keras import Model

ed_nofreeze = Model(inputs=ed.input, outputs=ed.layers[-4].output)

for layer in ed_nofreeze.layers:
  layer.trainable = True

# ed_nofreeze.summary()

# %% [markdown]
# ## CNN + LSTM

# %%
from keras.layers import TimeDistributed, Input, LSTM, Dense, Dropout

input_layer = Input(shape=(sequence_length, 224, 224, 3))
ed_reshaped = TimeDistributed(ed_nofreeze)(input_layer)
CNNandLSTM = LSTM(100, activation='relu')(ed_reshaped)
dropout = Dropout(0.5)(CNNandLSTM)
output = Dense(1, activation='sigmoid')(dropout)

model = Model(inputs=input_layer, outputs=output)
model.summary()

# %%
model.save('models/wild/ED_LSTM_wild_trainable_True.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # Inference with pre-trained CNN on single test frames

# %%
path = 'csv/Test/wild/KFold_long-range/fold2'
csvs = os.listdir(path)
test_data = {'filename':[], 'Flames':[]}

for csv in csvs:
    temp = pd.read_csv(path + '/' + csv)
    for index, row in temp.iterrows():
      test_data['filename'].append(row['filename'])
      test_data['Flames'].append(row['Flames'])

test_data = pd.DataFrame(test_data)
print("Test data samples: " + str(len(test_data)) + ".\nPositive test frames: " +
      str(test_data[test_data['Flames'] == 1].count()[0]) + ".\nNegative test frames: " +
      str(test_data[test_data['Flames'] == 0].count()[0]) + ".")

# %%
# putting our test data labels in the proper format and shape desired
col = test_data['Flames']
col = list(col)

t = []
for i in col:
  t.append(str(i))

td = {'filename':[], 'Flames':[]}

for index, row in test_data.iterrows():
  td['filename'].append(row['filename'])
  td['Flames'].append(t[index])

test_data = pd.DataFrame(td)

# %%
new_test_data = {'filename':[], 'Flames':[]}

for index, row in test_data.iterrows():
  new_test_data['filename'].append('/content/drive/My Drive' + row['filename'][30:])
  new_test_data['Flames'].append(str(row['Flames']))

n_t_d = pd.DataFrame(new_test_data)

# %%
import tensorflow
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard, CSVLogger, EarlyStopping

test_datagen = ImageDataGenerator(preprocessing_function = tensorflow.keras.applications.efficientnet.preprocess_input)

test_generator = test_datagen.flow_from_dataframe(dataframe = n_t_d, 
                                                    x_col='filename', 
                                                    y_col='Flames', 
                                                    class_mode='binary',
                                                    target_size=(224,224),
                                                    batch_size=32,
                                                    shuffle=False)

# %%
from keras.models import load_model

ed_path = 'models/wild/ED_wild_pre-trained.h5'
ed = load_model(ed_path)

pred = ed.predict(test_generator)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_cm(y, pred):
  p = pred.argmax(-1)
  cm = confusion_matrix(y, p)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot()
  plt.title('Accuracy: %.3f' % (y==p).mean())
  plt.show()

# %%
test_lab = []
for i in list(n_t_d['Flames']):
  test_lab.append(int(i))
plot_cm(y=test_lab, pred=pred)

# %% [markdown]
# # Evaluate

# %%
# tensorflow version must be the 2.6.2 and keras version must be 2.6.0.
# !pip install tensorflow==2.6.2
# %tensorflow_version 2.6.2

# !!!!!!!!!!!!!! AFTER EXECUTING THIS CELL, RESTART THE RUNTIME !!!!!!!!!!!!!!!!
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.6.2
#   Downloading tensorflow-2.6.2-cp38-cp38-manylinux2010_x86_64.whl (458.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.4/458.4 MB 3.4 MB/s eta 0:00:00
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2) (0.4.0)
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2) (3.3.0)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting keras<2.7,>=2.6.0
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.4 MB/s eta 0:00:00
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2) (1.15.0)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2) (1.51.1)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2) (3.1.0)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2) (3.19.6)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2) (1.6.3)
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.9/462.9 KB 51.1 MB/s eta 0:00:00
# Collecting tensorboard<2.7,>=2.6.0
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 109.7 MB/s eta 0:00:00
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp38-cp38-manylinux2010_x86_64.whl (14.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 82.7 MB/s eta 0:00:00
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2) (0.38.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (2.25.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (3.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (57.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (0.4.6)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 KB 25.2 MB/s eta 0:00:00
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (6.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (3.12.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (3.2.2)
# Building wheels for collected packages: clang, termcolor, wrapt
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30694 sha256=1f439ccd95f4c8a383d477076659010700cb66bb5753625562382aac0c96293c
#   Stored in directory: /root/.cache/pip/wheels/f1/60/77/22b9b5887bd47801796a856f47650d9789c74dc3161a26d608
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4849 sha256=4abacf74b27d97028496cb3a8949183afa0dfb4eb8fcbaa56ec9f463e494937a
#   Stored in directory: /root/.cache/pip/wheels/a0/16/9c/5473df82468f958445479c59e784896fa24f4a5fc024b0f501
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp38-cp38-linux_x86_64.whl size=78584 sha256=0d7904ea4f3ff2cc2e4205fccb4a45cc922ebb30d889803c5be1afb0577607b5
#   Stored in directory: /root/.cache/pip/wheels/5f/fd/9e/b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
# Successfully built clang termcolor wrapt
# Installing collected packages: wrapt, typing-extensions, termcolor, tensorflow-estimator, keras, flatbuffers, clang, numpy, cachetools, absl-py, keras-preprocessing, google-auth, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.2.0
#     Uninstalling termcolor-2.2.0:
#       Successfully uninstalled termcolor-2.2.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.1.21
#     Uninstalling flatbuffers-23.1.21:
#       Successfully uninstalled flatbuffers-23.1.21
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.0
#     Uninstalling cachetools-5.3.0:
#       Successfully uninstalled cachetools-5.3.0
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.16.0
#     Uninstalling google-auth-2.16.0:
#       Successfully uninstalled google-auth-2.16.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# xarray-einstats 0.5.1 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# pydantic 1.10.4 requires typing-extensions>=4.2.0, but you have typing-extensions 3.7.4.3 which is incompatible.
# jaxlib 0.3.25+cuda11.cudnn805 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# jax 0.3.25 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# google-api-core 2.11.0 requires google-auth<3.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# cmdstanpy 1.1.0 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
# Successfully installed absl-py-0.15.0 cachetools-4.2.4 clang-5.0 flatbuffers-1.12 google-auth-1.35.0 keras-2.6.0 keras-preprocessing-1.1.2 numpy-1.19.5 tensorboard-2.6.0 tensorflow-2.6.2 tensorflow-estimator-2.6.0 termcolor-1.1.0 typing-extensions-3.7.4.3 wrapt-1.12.1
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.6.2

# %%
from tensorflow import keras
print(keras.__version__)
# Out:
# 2.6.0

# %%
import os
import cv2
import math
import copy
import random
import numpy as np
import pandas as pd
import albumentations as A
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from keras.models import load_model
from tensorflow.keras.utils import Sequence
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.optimizers import SGD
import warnings
warnings.filterwarnings('ignore')



sequence_length = 4
sequence_stride = 2
batch_size      = 16

def file_generator(data_path, data_files, temporal_stride, temporal_length):
  '''
  data_files - list of csv files to be read
  '''
  for f in data_files:
    tmp_df = pd.read_csv(os.path.join(data_path, f))
    total_images = len(tmp_df)
    if total_images >= temporal_length:
      num_samples = int((total_images - temporal_length)/temporal_stride) + 1
      # print('num of samples from vid seq-{}: {}'.format(f, num_samples))
    else:
      # print('num of frames is less than temporal length; hence discarding this \
      #       file-{}'.format(f))
      continue

    samples = deque()
    labels = deque()

    for index, row in tmp_df.iterrows():
      samples.append('/content/drive/My Drive' + row['filename'][30:])
      labels.append(int(row['Flames']))
      if len(samples) == temporal_length:
        to_delete = False
        if labels.count(labels[0]) != len(labels):
          to_delete = True
        samples_c = copy.deepcopy(samples)
        for t in range(temporal_stride):
          samples.popleft()
          labels.popleft()
        if to_delete: continue
        yield samples_c, labels[0]

def load_samples(CSV_folder, temporal_stride, temporal_length):
  data_path = os.path.join('csv', CSV_folder)
  data_files = os.listdir(data_path)
  file_gen = file_generator(data_path, data_files, temporal_stride, temporal_length)
  iterator = True
  data_list = []

  while iterator:
    try:
      x, y = next(file_gen)
      x = list(x)
      data_list.append([x, y])
    except Exception as e:
      # print('Exception: ', e)
      iterator = False
      # print('end of data generator ')
  return data_list

class DataGenerator(Sequence):

    def __init__(self, data, batch_size, shuffle_data, aug):
        self.num_samples = len(data)
        self.data = shuffle(data) if shuffle_data else data
        self.batch_size = batch_size
        self.aug = aug        
        self.additional_targets = {[f'image{i}' for i in range(sequence_length-1)][j]:'image' for j in range(sequence_length-1)}

    def __len__(self):
        return math.ceil(len(self.data) / self.batch_size)

    def __getitem__(self, idx):
        #print('starting index: ', idx * self.batch_size)
        batch_samples = self.data[idx * self.batch_size:(idx + 1) * self.batch_size]
        X_train = []
        y_train = []
        for batch_sample in batch_samples:
            x = batch_sample[0]   # Load image (X)
            y = batch_sample[1]   # Read label (y)
            temp_data_list = []
            for img_name in x:
                try:
                    img = cv2.imread(img_name)
                    img = cv2.resize(img, (224,224))
                    temp_data_list.append(img[:,:, ::-1])
                except Exception as e:
                    print(e)
                    print('error reading file: ', img_name)
            # if self.aug:
            #     temp_data_list = self.__totransform__(temp_data_list)
            # Add example to arrays
            X_train.append(temp_data_list)
            y_train.append(y)
        # Make sure they're numpy arrays (as opposed to lists)
        X_train = np.array(X_train)
        y_train = np.array(y_train)
        return X_train, y_train

test_data = load_samples(CSV_folder='Test/wild/KFold_long-range/fold2', temporal_stride=sequence_stride,
                            temporal_length=sequence_length)

test_gen = DataGenerator(data=test_data, batch_size=batch_size, 
                         shuffle_data=False, aug=False)

model = load_model('models/wild/long-range/EfficientDet/case8/case8_best_model2.h5')

groundtruth = []
for sample in test_data:
  groundtruth.append(sample[1])

pred = model.predict(test_gen)
predictions = []
for i in range(len(pred)):
  if pred[i][0] > 0.5:
    predictions.append(1)
  else:
    predictions.append(0)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_cm(data, pred):
  y = np.array(data)
  p = np.array(pred)
  cm = confusion_matrix(y, p)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot()
  plt.title('Accuracy: %.3f' % (y==p).mean())
  plt.show()
plot_cm(data=groundtruth, pred=predictions)

# %%
model.evaluate(test_gen)
# Out:
# 55/55 [==============================] - 247s 4s/step - loss: 0.0542 - accuracy: 0.9804
# [0.054189179092645645, 0.9804372787475586]

# %%
p = []
for i in pred:
  p.append(round(list(i)[0]))
p = np.array(p)
y = np.array(groundtruth)

groundtruth = list(y)
scores = list(p)

# %%
from keras.metrics import AUC # Approximates the Area Under the Curve of the ROC curve
from sklearn.metrics import balanced_accuracy_score

b_acc = balanced_accuracy_score(y_true=y, y_pred=p)

TP=TN=FP=FN = 0

for i in range(len(groundtruth)):
    if groundtruth[i] == 1 and scores[i] == 1:
        TP = TP + 1
    elif groundtruth[i] == 0 and scores[i] == 0:
        TN = TN + 1
    elif groundtruth[i] == 0 and scores[i] == 1:
        FP = FP + 1
    elif groundtruth[i] == 1 and scores[i] == 0:
        FN = FN + 1

AR = (TP + TN)/(TP + TN + FP + FN)
Precision = TP/(TP + FP)
Recall = TP/(TP + FN)
TPR = TP/(TP + FN)
TNR = TN/(TN + FP)
FPR = FP/(FP + TN)
FNR = FN/(FN + TP)
F1score = (2 * Precision * Recall)/(Precision + Recall)
Auc = AUC()
Auc.update_state(groundtruth, scores)

print("True Positives: " + str(TP) + "\nTrue Negatives: " + str(TN) + 
      "\nFalse Positives: " + str(FP) + "\nFalse Negatives: " + str(FN) +
      "\nTrue Positive rate: " + str(round(TPR, 3)) + "\nTrue negative rate: " +
      str(round(TNR, 3)) + "\nFalse Positive rate: " + str(round(FPR, 3)) +
      "\nFalse Negative rate: " + str(round(FNR, 3)) + "\nAccuracy Rate: " + 
      str(round(AR, 3)) + "\nPrecision: " + str(round(Precision, 3)) + 
      "\nRecall: " + str(round(Recall, 3)) + "\nBalanced accuracy: " + 
      str(round(b_acc, 3)) + "\nF1-Score: " + str(round(F1score, 3)) + 
      "\nArea under ROC curve: " + str(round(float(Auc.result()), 3)))
# Out:
# True Positives: 201
# True Negatives: 651
# False Positives: 9
# False Negatives: 8
# True Positive rate: 0.962
# True negative rate: 0.986
# False Positive rate: 0.014
# False Negative rate: 0.038
# Accuracy Rate: 0.98
# Precision: 0.957
# Recall: 0.962
# Balanced accuracy: 0.974
# F1-Score: 0.959
# Area under ROC curve: 0.974

# %%
from sklearn.metrics import roc_curve

def plot_roc_curve(fpr,tpr): 
  plt.plot(fpr,tpr) 
  plt.axis([0,1,0,1]) 
  plt.xlabel('False Positive Rate') 
  plt.ylabel('True Positive Rate') 
  plt.show()

p = []
for i in pred:
  p.append(round(list(i)[0]))
p = np.array(p)

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_true=np.array(groundtruth), y_score=p)
plot_roc_curve(fpr_keras,tpr_keras)

# %% [markdown]
# ## Which samples are wrongly predicted?

# %%
wrong_predictions01 = []

for i in range(len(groundtruth)):
    if test_data[i][1] == 0 and scores[i] == 1:
      wrong_predictions01.append(test_data[i][0])
for i in range(len(wrong_predictions01)):
  print(wrong_predictions01[i])
# Out:
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/7.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/8.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/9.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/10.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/9.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/10.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/11.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/12.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/15.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/16.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/17.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/18.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/17.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/18.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/19.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/20.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/19.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/20.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/21.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/22.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/21.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/22.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/23.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/24.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/23.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/24.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/25.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/26.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/25.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/26.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/27.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/28.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/27.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/28.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/29.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/negative/fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4/30.jpg']

# %%
wrong_predictions10 = []

for i in range(len(groundtruth)):
    if test_data[i][1] == 1 and scores[i] == 0:
      
      wrong_predictions10.append(test_data[i][0])
for i in range(len(wrong_predictions10)):
  print(wrong_predictions10[i])
# Out:
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/positive/smoke-billows-in-a-pine-forest-during-a-wildfire-SBV-320534561-preview.mp4/13.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/positive/smoke-billows-in-a-pine-forest-during-a-wildfire-SBV-320534561-preview.mp4/14.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/positive/smoke-billows-in-a-pine-forest-during-a-wildfire-SBV-320534561-preview.mp4/15.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/positive/smoke-billows-in-a-pine-forest-during-a-wildfire-SBV-320534561-preview.mp4/16.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/positive/smoke-billows-in-a-pine-forest-during-a-wildfire-SBV-320534561-preview.mp4/15.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/positive/smoke-billows-in-a-pine-forest-during-a-wildfire-SBV-320534561-preview.mp4/16.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/positive/smoke-billows-in-a-pine-forest-during-a-wildfire-SBV-320534561-preview.mp4/17.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/Storyblocks/frames/positive/smoke-billows-in-a-pine-forest-during-a-wildfire-SBV-320534561-preview.mp4/18.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/1.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/2.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/3.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/4.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/3.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/4.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/5.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/6.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/15.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/16.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/17.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/18.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/17.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/18.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/19.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/20.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/19.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/20.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/21.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/22.jpg']
# ['/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/21.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/22.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/23.jpg', '/content/drive/My Drive/Tesi/datasets/wild/long-range/iStock/frames/positive/istockphoto-935334294-640_adpp_is.mp4/24.jpg']

# %%
all_videos = {'name':[], 'num':[]}

video_name = test_data[0][0][0]
uno = video_name[54:]
revers_uno = uno[::-1]
last_slash = revers_uno.index('/') + 1
semifinal = video_name[54:-last_slash]
rev = semifinal[::-1]
penultimo = rev.index('/')
final = semifinal[-penultimo:]
temp = final
count = 0

for list_of_lists in test_data:
  video_name = list_of_lists[0][0]
  uno = video_name[54:]
  revers_uno = uno[::-1]
  last_slash = revers_uno.index('/') + 1
  semifinal = video_name[54:-last_slash]
  rev = semifinal[::-1]
  penultimo = rev.index('/')
  final = semifinal[-penultimo:]
  
  if final != temp:
    all_videos['name'].append(temp)
    all_videos['num'].append(count)
    count = 0
    temp = final
  count += 1
all_videos['name'].append(temp)
all_videos['num'].append(count)

df = pd.DataFrame(all_videos)
df
# Out:
#                                                  name  num
# 0   view-from-the-height-of-mountains-covered-with...   16
# 1   view-from-the-height-on-a-bright-autumn-forest...   34
# 2   wildfire-burns-ground-in-forest-SBV-346994711-...    9
# 3                    smoke_or_flame_like_object_9.avi   24
# 4   raging-mountain-forest-fire-SBV-301039310-prev...    7
# 5   smoke-billows-in-a-pine-forest-during-a-wildfi...   10
# 6   march-2017-eruption-on-mount-etna-in-sicily-so...   10
# 7   picturesque-natural-scenery-of-forest-rice-ter...   44
# 8   smoke-filled-sky-at-sunset-with-tree-SBV-32691...   24
# 9   large-flames-and-smoke-of-a-forest-fire-fire-0...   19
# 10              istockphoto-479315483-640_adpp_is.mp4   13
# 11             istockphoto-1318319143-640_adpp_is.mp4   18
# 12             istockphoto-1317625168-640_adpp_is.mp4   12
# 13  lake-scenes-in-mountains-national-park-of-domb...   30
# 14              istockphoto-935334294-640_adpp_is.mp4   19
# 15             istockphoto-1292024067-640_adpp_is.mp4   15
# 16              istockphoto-864754036-640_adpp_is.mp4   14
# 17             istockphoto-1299407782-640_adpp_is.mp4   11
# 18              istockphoto-893388370-640_adpp_is.mp4   31
# 19             istockphoto-1225189918-640_adpp_is.mp4   25
# 20  flight-above-forest-an-mountains-SBV-315904786...   41
# 21             istockphoto-1023612474-640_adpp_is.mp4   51
# 22  forest-fire-burns-near-homes-SBV-300147547-pre...    7
# 23       forest-fire-raging-SBV-300171850-preview.mp4   11
# 24             istockphoto-1173910629-640_adpp_is.mp4   36
# 25  fire-fighter-plane-drops-fire-retardant-on-a-f...   14
# 26  firefighters-managing-wildfire-SBV-301031577-p...    9
# 27             istockphoto-1207209216-640_adpp_is.mp4   19
# 28  fire-during-a-fire-the-flames-of-red-burn-slow...   10
# 29  epic-green-landscape-of-amazing-pristine-untou...   43
# 30  colorful-trees-in-the-fall-01-drone-view-SBV-3...    7
# 31  depositphotos_329648120-stock-video-winding-pa...   27
# 32  aerial-view-of-the-lake-and-forest-in-finland-...   47
# 33  aerial-view-flying-over-the-beautiful-mountain...    9
# 34  aerial-view-of-the-beautiful-landscape-the-riv...   42
# 35  colorful-trees-in-the-fall-01-drone-view-SBV-3...   14
# 36  aerial-view-of-a-burning-dry-field-large-cloud...   20
# 37  aerial-view-dangerous-fire-in-the-field-night-...   17
# 38  aerial-flight-over-primary-tropical-rainforest...   28
# 39  aerial-drone-shot-of-forest-at-sunset-lens-fla...   32

# %%
for index,row in df.iterrows():
  print(row['name'])
# Out:
# view-from-the-height-of-mountains-covered-with-coniferous-forest-and-morning-f-SBV-332475102-preview.mp4
# view-from-the-height-on-a-bright-autumn-forest-SBV-338788419-preview.mp4
# wildfire-burns-ground-in-forest-SBV-346994711-preview.mp4
# smoke_or_flame_like_object_9.avi
# raging-mountain-forest-fire-SBV-301039310-preview.mp4
# smoke-billows-in-a-pine-forest-during-a-wildfire-SBV-320534561-preview.mp4
# march-2017-eruption-on-mount-etna-in-sicily-southern-italy-the-largest-active--SBV-313525325-preview.mp4
# picturesque-natural-scenery-of-forest-rice-terraces-waterfalls-and-wavy-road-SBV-338907192-preview.mp4
# smoke-filled-sky-at-sunset-with-tree-SBV-326919852-preview.mp4
# large-flames-and-smoke-of-a-forest-fire-fire-01mov-SBV-301020935-preview.mp4
# istockphoto-479315483-640_adpp_is.mp4
# istockphoto-1318319143-640_adpp_is.mp4
# istockphoto-1317625168-640_adpp_is.mp4
# lake-scenes-in-mountains-national-park-of-dombay-caucasus-russia-summer-landsc-SBV-337461731-preview.mp4
# istockphoto-935334294-640_adpp_is.mp4
# istockphoto-1292024067-640_adpp_is.mp4
# istockphoto-864754036-640_adpp_is.mp4
# istockphoto-1299407782-640_adpp_is.mp4
# istockphoto-893388370-640_adpp_is.mp4
# istockphoto-1225189918-640_adpp_is.mp4
# flight-above-forest-an-mountains-SBV-315904786-preview.mp4
# istockphoto-1023612474-640_adpp_is.mp4
# forest-fire-burns-near-homes-SBV-300147547-preview.mp4
# forest-fire-raging-SBV-300171850-preview.mp4
# istockphoto-1173910629-640_adpp_is.mp4
# fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4
# firefighters-managing-wildfire-SBV-301031577-preview.mp4
# istockphoto-1207209216-640_adpp_is.mp4
# fire-during-a-fire-the-flames-of-red-burn-slowly-small-fire-against-a-dark-bac-SBV-338350799-preview.mp4
# epic-green-landscape-of-amazing-pristine-untouched-nature-of-alpine-mountains--SBV-331347835-preview.mp4
# colorful-trees-in-the-fall-01-drone-view-SBV-338785198-preview.mp4
# depositphotos_329648120-stock-video-winding-park-path-covered-with.mp4
# aerial-view-of-the-lake-and-forest-in-finland-beautiful-nature-of-finland-SBV-337999986-preview.mp4
# aerial-view-flying-over-the-beautiful-mountain-river-and-beautiful-forest-aeri-SBV-317227748-preview.mp4
# aerial-view-of-the-beautiful-landscape-the-river-flows-among-the-green-deciduo-SBV-336328951-preview.mp4
# colorful-trees-in-the-fall-01-drone-view-SBV-338785198-preview2.mp4
# aerial-view-of-a-burning-dry-field-large-clouds-of-smoke-rise-into-the-sky-ton-SBV-347246367-preview.mp4
# aerial-view-dangerous-fire-in-the-field-night-fire-natural-disaster-SBV-337658397-preview.mp4
# aerial-flight-over-primary-tropical-rainforest-foggy-and-mystic-sal-guiana-ama-SBV-328051801-preview.mp4
# aerial-drone-shot-of-forest-at-sunset-lens-flare-wilderness-trees-in-vermont-SBV-334645566-preview.mp4

# %%
all_videos = {'name':[], 'num':[]}

video_name = wrong_predictions10[0][0]
uno = video_name[54:]
revers_uno = uno[::-1]
last_slash = revers_uno.index('/') + 1
semifinal = video_name[54:-last_slash]
rev = semifinal[::-1]
penultimo = rev.index('/')
final = semifinal[-penultimo:]
temp = final
count = 0

for list_of_lists in wrong_predictions10:
  video_name = list_of_lists[0]
  uno = video_name[54:]
  revers_uno = uno[::-1]
  last_slash = revers_uno.index('/') + 1
  semifinal = video_name[54:-last_slash]
  rev = semifinal[::-1]
  penultimo = rev.index('/')
  final = semifinal[-penultimo:]
  
  if final != temp:
    all_videos['name'].append(temp)
    all_videos['num'].append(count)
    count = 0
    temp = final
  count += 1
all_videos['name'].append(temp)
all_videos['num'].append(count)

df_wrong10 = pd.DataFrame(all_videos)
# Out:
#                                                 name  num
# 0  smoke-billows-in-a-pine-forest-during-a-wildfi...    2
# 1              istockphoto-935334294-640_adpp_is.mp4    6

# %%
for index,row in df_wrong10.iterrows():
  print(row['name'])
# Out:
# smoke-billows-in-a-pine-forest-during-a-wildfire-SBV-320534561-preview.mp4
# istockphoto-935334294-640_adpp_is.mp4

# %%
all_videos = {'name':[], 'num':[]}

video_name = wrong_predictions01[0][0]
uno = video_name[54:]
revers_uno = uno[::-1]
last_slash = revers_uno.index('/') + 1
semifinal = video_name[54:-last_slash]
rev = semifinal[::-1]
penultimo = rev.index('/')
final = semifinal[-penultimo:]
temp = final
count = 0

for list_of_lists in wrong_predictions01:
  video_name = list_of_lists[0]
  uno = video_name[54:]
  revers_uno = uno[::-1]
  last_slash = revers_uno.index('/') + 1
  semifinal = video_name[54:-last_slash]
  rev = semifinal[::-1]
  penultimo = rev.index('/')
  final = semifinal[-penultimo:]
  
  if final != temp:
    all_videos['name'].append(temp)
    all_videos['num'].append(count)
    count = 0
    temp = final
  count += 1
all_videos['name'].append(temp)
all_videos['num'].append(count)

df_wrong01 = pd.DataFrame(all_videos)
df_wrong01
# Out:
#                                                 name  num
# 0  fire-fighter-plane-drops-fire-retardant-on-a-f...    9

# %%
for index,row in df_wrong01.iterrows():
  print(row['name'])
# Out:
# fire-fighter-plane-drops-fire-retardant-on-a-forest-fire-in-the-hills-SBV-338590163-preview.mp4
