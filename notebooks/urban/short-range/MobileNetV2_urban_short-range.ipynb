# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/Tesi')

# %%
import cv2
import math
import copy
import random
import numpy as np
import pandas as pd
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from keras.models import load_model
from tensorflow.keras.utils import Sequence

import warnings
warnings.filterwarnings('ignore')

# %%
sequence_length = 4
sequence_stride = 2
batch_size      = 16

# %% [markdown]
# # Network model

# %% [markdown]
# ## Loading the pre-trained model

# %%
mnv2_path = 'models/urban/MNV2_urban_pre-trained.h5'
mnv2 = load_model(mnv2_path)

mnv2.summary()

# %% [markdown]
# ## Remove the top layers

# %%
from keras import Model

mnv2_nofreeze = Model(inputs=mnv2.input, outputs=mnv2.layers[-4].output)

for layer in mnv2_nofreeze.layers:
  layer.trainable = True

# mnv2_nofreeze.summary()

# %% [markdown]
# ## CNN + LSTM

# %%
from keras.layers import TimeDistributed, Input, LSTM, Dense, Dropout

input_layer = Input(shape=(sequence_length, 224, 224, 3))
mnv2_reshaped = TimeDistributed(mnv2_nofreeze)(input_layer)
CNNandLSTM = LSTM(100, activation='relu')(mnv2_reshaped)
dropout = Dropout(0.5)(CNNandLSTM)
output = Dense(1, activation='sigmoid')(dropout)

model = Model(inputs=input_layer, outputs=output)
model.summary()

# %%
model.save('models/urban/MNV2_urban_trainable_True.h5')

# %% [markdown]
# # Inference with pre-trained CNN on single test frames

# %%
path = 'csv/Test/urban/KFold_short-range/fold5'
csvs = os.listdir(path)
test_data = {'filename':[], 'Flames':[]}

for csv in csvs:
    temp = pd.read_csv(path + '/' + csv)
    for index, row in temp.iterrows():
      test_data['filename'].append(row['filename'])
      test_data['Flames'].append(row['Flames'])

test_data = pd.DataFrame(test_data)
print("Test data samples: " + str(len(test_data)) + ".\nPositive test frames: " +
      str(test_data[test_data['Flames'] == 1].count()[0]) + ".\nNegative test frames: " +
      str(test_data[test_data['Flames'] == 0].count()[0]) + ".")

# %%
# putting our test data labels in the proper format and shape desired
col = test_data['Flames']
col = list(col)

t = []
for i in col:
  t.append(str(i))

td = {'filename':[], 'Flames':[]}

for index, row in test_data.iterrows():
  td['filename'].append(row['filename'])
  td['Flames'].append(t[index])

test_data = pd.DataFrame(td)

# %%
new_test_data = {'filename':[], 'Flames':[]}

for index, row in test_data.iterrows():
  new_test_data['filename'].append('/content/drive/My Drive' + row['filename'][30:])
  new_test_data['Flames'].append(str(row['Flames']))

n_t_d = pd.DataFrame(new_test_data)

# %%
from keras.applications.imagenet_utils import preprocess_input

def preproc_function(img):
  image_t = preprocess_input(x = img, mode = 'tf')
  return image_t

# %%
import tensorflow
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard, CSVLogger, EarlyStopping

test_datagen = ImageDataGenerator(preprocessing_function = preproc_function)

test_generator = test_datagen.flow_from_dataframe(dataframe = n_t_d, 
                                                    x_col='filename', 
                                                    y_col='Flames', 
                                                    class_mode='binary',
                                                    target_size=(224,224),
                                                    batch_size=32,
                                                    shuffle=False)

# %%
from keras.models import load_model

mnv2_path = 'models/urban/MNV2_urban_pre-trained.h5'
mnv2 = load_model(mnv2_path)

pred = mnv2.predict(test_generator)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_cm(y, pred):
  p = pred.argmax(-1)
  cm = confusion_matrix(y, p)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot()
  plt.title('Accuracy: %.3f' % (y==p).mean())
  plt.show()

# %%
test_lab = []
for i in list(n_t_d['Flames']):
  test_lab.append(int(i))
plot_cm(y=test_lab, pred=pred)

# %% [markdown]
# # Evaluate

# %%
class DataGenerator(Sequence):

    def __init__(self, data, batch_size, shuffle_data, aug):
        self.num_samples = len(data)
        self.data = shuffle(data) if shuffle_data else data
        self.batch_size = batch_size
        self.aug = aug        
        self.additional_targets = {[f'image{i}' for i in range(sequence_length-1)][j]:'image' for j in range(sequence_length-1)}

    def __len__(self):
        return math.ceil(len(self.data) / self.batch_size)

    def __getitem__(self, idx):
        #print('starting index: ', idx * self.batch_size)
        batch_samples = self.data[idx * self.batch_size:(idx + 1) * self.batch_size]
        X_train = []
        y_train = []
        for batch_sample in batch_samples:
            x = batch_sample[0]   # Load image (X)
            y = batch_sample[1]   # Read label (y)
            temp_data_list = []
            for img_name in x:
                try:
                    img = cv2.imread(img_name)
                    img = cv2.resize(img, (224,224))
                    temp_data_list.append(img[:,:, ::-1])
                except Exception as e:
                    print(e)
                    print('error reading file: ', img_name)
            # if self.aug:
            #     temp_data_list = self.__totransform__(temp_data_list)
            # Add example to arrays
            X_train.append(temp_data_list)
            y_train.append(y)
        # Make sure they're numpy arrays (as opposed to lists)
        X_train = np.array(X_train)
        y_train = np.array(y_train)
        return X_train, y_train

# %%
def file_generator(data_path, data_files, temporal_stride, temporal_length):
  '''
  data_files - list of csv files to be read
  '''
  for f in data_files:
    tmp_df = pd.read_csv(os.path.join(data_path, f))
    total_images = len(tmp_df)
    if total_images >= temporal_length:
      num_samples = int((total_images - temporal_length)/temporal_stride) + 1
      #print('num of samples from vid seq-{}: {}'.format(f, num_samples))
    else:
      #print('num of frames is less than temporal length; hence discarding this \
      #      file-{}'.format(f))
      continue

    samples = deque()
    labels = deque()

    for index, row in tmp_df.iterrows():
      samples.append('/content/drive/My Drive' + row['filename'][30:])
      labels.append(int(row['Flames']))
      if len(samples) == temporal_length:
        to_delete = False
        if labels.count(labels[0]) != len(labels):
          to_delete = True
        samples_c = copy.deepcopy(samples)
        for t in range(temporal_stride):
          samples.popleft()
          labels.popleft()
        if to_delete: continue
        yield samples_c, labels[0]

def load_samples(CSV_folder, temporal_stride, temporal_length):
  data_path = os.path.join('csv', CSV_folder)
  data_files = os.listdir(data_path)
  file_gen = file_generator(data_path, data_files, temporal_stride, temporal_length)
  iterator = True
  data_list = []

  while iterator:
    try:
      x, y = next(file_gen)
      x = list(x)
      data_list.append([x, y])
    except Exception as e:
      #print('Exception: ', e)
      iterator = False
      #print('end of data generator ')
  return data_list

test_data = load_samples(CSV_folder='Test/urban/KFold_short-range/fold5', 
                            temporal_stride=sequence_stride,
                            temporal_length=sequence_length)

test_gen = DataGenerator(data=test_data, batch_size=batch_size, 
                         shuffle_data=False, aug=False)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_cm(y, pred):
  p = []
  for i in pred:
    p.append(round(list(i)[0]))
  p = np.array(p)
  y = np.array(y)
  cm = confusion_matrix(y, p)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot()
  plt.title('Accuracy: %.3f' % (y==p).mean())
  plt.show()

model = load_model('models/urban/short-range/MobileNetV2/case14/case14_best_model5.h5')

test_labels = []
for test in range(len(test_data)):
  test_labels.append(test_data[test][1])

pred = model.predict(test_gen)
plot_cm(y=test_labels, pred=list(pred))
# Out:
# 78/78 [==============================] - 2014s 26s/step

# %%
model.evaluate(test_gen)
# Out:
# 78/78 [==============================] - 278s 4s/step - loss: 0.1377 - accuracy: 0.9483
# [0.13769970834255219, 0.9483036994934082]

# %%
p = []
for i in pred:
  p.append(round(list(i)[0]))
p = np.array(p)
y = np.array(test_labels)

test_labels = list(y)
scores = list(p)

# %%
from keras.metrics import AUC # Approximates the Area Under the Curve of the ROC curve
from sklearn.metrics import balanced_accuracy_score

b_acc = balanced_accuracy_score(y_true=y, y_pred=p)

TP=TN=FP=FN = 0

for i in range(len(test_labels)):
    if test_labels[i] == 1 and scores[i] == 1:
        TP = TP + 1
    elif test_labels[i] == 0 and scores[i] == 0:
        TN = TN + 1
    elif test_labels[i] == 0 and scores[i] == 1:
        FP = FP + 1
    elif test_labels[i] == 1 and scores[i] == 0:
        FN = FN + 1

AR = (TP + TN)/(TP + TN + FP + FN)
Precision = TP/(TP + FP)
Recall = TP/(TP + FN)
TPR = TP/(TP + FN)
TNR = TN/(TN + FP)
FPR = FP/(FP + TN)
FNR = FN/(FN + TP)
F1score = (2 * Precision * Recall)/(Precision + Recall)
Auc = AUC()
Auc.update_state(test_labels, scores)

print("True Positives: " + str(TP) + "\nTrue Negatives: " + str(TN) + 
      "\nFalse Positives: " + str(FP) + "\nFalse Negatives: " + str(FN) +
      "\nTrue Positive rate: " + str(round(TPR, 3)) + "\nTrue negative rate: " +
      str(round(TNR, 3)) + "\nFalse Positive rate: " + str(round(FPR, 3)) +
      "\nFalse Negative rate: " + str(round(FNR, 3)) + "\nAccuracy Rate: " + 
      str(round(AR, 3)) + "\nPrecision: " + str(round(Precision, 3)) + 
      "\nRecall: " + str(round(Recall, 3)) + "\nBalanced accuracy: " + 
      str(round(b_acc, 3)) + "\nF1-Score: " + str(round(F1score, 3)) + 
      "\nArea under ROC curve: " + str(round(float(Auc.result()), 3)))
# Out:
# True Positives: 662
# True Negatives: 512
# False Positives: 4
# False Negatives: 60
# True Positive rate: 0.917
# True negative rate: 0.992
# False Positive rate: 0.008
# False Negative rate: 0.083
# Accuracy Rate: 0.948
# Precision: 0.994
# Recall: 0.917
# Balanced accuracy: 0.955
# F1-Score: 0.954
# Area under ROC curve: 0.955

# %%
from sklearn.metrics import roc_curve

def plot_roc_curve(fpr,tpr): 
  plt.plot(fpr,tpr) 
  plt.axis([0,1,0,1]) 
  plt.xlabel('False Positive Rate') 
  plt.ylabel('True Positive Rate') 
  plt.show()

p = []
for i in pred:
  p.append(round(list(i)[0]))
p = np.array(p)

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_true=np.array(test_labels), y_score=p)
plot_roc_curve(fpr_keras,tpr_keras)

# %% [markdown]
# ## Which samples are wrongly predicted?

# %%
wrong_predictions01 = []
wrong_predictions10 = []

for i in range(len(test_labels)):
    if test_data[i][1] == 0 and scores[i] == 1:
      wrong_predictions01.append(test_data[i][0])
    if test_data[i][1] == 1 and scores[i] == 0:
      wrong_predictions10.append(test_data[i][0])

# %%
all_videos = {'name':[], 'num':[]}

video_name = wrong_predictions01[0][0]
uno = video_name[56:]
revers_uno = uno[::-1]
last_slash = revers_uno.index('/') + 1
semifinal = video_name[56:-last_slash]
rev = semifinal[::-1]
penultimo = rev.index('/')
final = semifinal[-penultimo:]
temp = final
count = 0

for list_of_lists in wrong_predictions01:
  video_name = list_of_lists[0]
  uno = video_name[56:]
  revers_uno = uno[::-1]
  last_slash = revers_uno.index('/') + 1
  semifinal = video_name[56:-last_slash]
  rev = semifinal[::-1]
  penultimo = rev.index('/')
  final = semifinal[-penultimo:]
  
  if final != temp:
    all_videos['name'].append(temp)
    all_videos['num'].append(count)
    count = 0
    temp = final
  count += 1
all_videos['name'].append(temp)
all_videos['num'].append(count)

df_wrong01 = pd.DataFrame(all_videos)
df_wrong01
# Out:
#                                      name  num
# 0                       testpos01.817.avi    2
# 1  istockphoto-1034430690-640_adpp_is.mp4    1
# 2              FlashoverDemonstration.mp4    1

# %%
all_videos = {'name':[], 'num':[]}

video_name = wrong_predictions10[0][0]
uno = video_name[56:]
revers_uno = uno[::-1]
last_slash = revers_uno.index('/') + 1
semifinal = video_name[56:-last_slash]
rev = semifinal[::-1]
penultimo = rev.index('/')
final = semifinal[-penultimo:]
temp = final
count = 0

for list_of_lists in wrong_predictions10:
  video_name = list_of_lists[0]
  uno = video_name[56:]
  revers_uno = uno[::-1]
  last_slash = revers_uno.index('/') + 1
  semifinal = video_name[56:-last_slash]
  rev = semifinal[::-1]
  penultimo = rev.index('/')
  final = semifinal[-penultimo:]
  
  if final != temp:
    all_videos['name'].append(temp)
    all_videos['num'].append(count)
    count = 0
    temp = final
  count += 1
all_videos['name'].append(temp)
all_videos['num'].append(count)

df_wrong10 = pd.DataFrame(all_videos)
df_wrong10
# Out:
#                                                 name  num
# 0  depositphotos_162701594-stock-video-fire-billo...   21
# 1                                         house6.mp4    4
# 2                                          fire2.mp4    4
# 3                                          test1.mp4   20
# 4                                         flame2.avi    8
# 5  modern-warfare-soldier-in-action-near-window-c...    3

# %%
wrong_predictions01
# Out:
# [['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testpos01.817.avi/27.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testpos01.817.avi/28.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testpos01.817.avi/29.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testpos01.817.avi/30.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testpos01.817.avi/29.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testpos01.817.avi/30.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testpos01.817.avi/31.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testpos01.817.avi/32.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/iStock/frames/negative/istockphoto-1034430690-640_adpp_is.mp4/11.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/iStock/frames/negative/istockphoto-1034430690-640_adpp_is.mp4/12.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/iStock/frames/negative/istockphoto-1034430690-640_adpp_is.mp4/13.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/iStock/frames/negative/istockphoto-1034430690-640_adpp_is.mp4/14.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/dunnings/frames/negative/FlashoverDemonstration.mp4/464.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/dunnings/frames/negative/FlashoverDemonstration.mp4/465.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/dunnings/frames/negative/FlashoverDemonstration.mp4/466.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/dunnings/frames/negative/FlashoverDemonstration.mp4/467.jpg']]

# %%
wrong_predictions10
# Out:
# [['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/1.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/2.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/4.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/4.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/6.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/6.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/8.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/8.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/10.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/10.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/11.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/12.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/11.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/12.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/13.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/14.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/13.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/14.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/15.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/16.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/15.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/16.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/17.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/18.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/17.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/18.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/19.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/20.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/19.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/20.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/21.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/22.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/21.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/22.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/23.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/24.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/23.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/24.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/25.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/26.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/25.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/26.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/27.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/28.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/27.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/28.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/29.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/30.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/29.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/30.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/31.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/32.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/31.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/32.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/33.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/34.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/33.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/34.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/35.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/36.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/35.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/36.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/37.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/38.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/37.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/38.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/39.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/40.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/43.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/44.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/45.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/46.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/45.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/46.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/47.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Depositphotos/frames/positive/depositphotos_162701594-stock-video-fire-billowing-inside-a-wooden.mp4/48.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/1.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/2.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/4.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/4.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/6.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/8.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/10.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/10.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/11.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Furg Fire dataset/frames/positive/house6.mp4/12.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/78.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/79.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/80.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/81.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/80.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/81.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/82.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/83.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/82.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/83.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/84.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/85.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/100.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/101.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/102.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/fire2.mp4/103.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/6.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/8.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/9.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/8.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/10.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/11.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/10.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/11.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/12.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/13.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/12.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/13.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/14.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/15.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/14.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/15.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/16.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/17.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/27.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/28.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/29.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/30.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/29.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/30.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/31.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/32.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/31.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/32.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/33.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/34.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/33.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/34.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/35.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/36.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/35.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/36.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/37.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/38.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/37.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/38.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/39.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/40.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/39.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/40.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/41.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/42.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/41.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/42.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/43.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/44.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/43.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/44.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/45.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/46.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/45.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/46.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/47.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/48.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/47.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/48.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/49.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/50.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/49.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/50.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/51.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/52.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/51.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/52.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/53.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/54.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/53.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/54.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/55.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/56.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/55.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/56.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/57.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Kaggle_ashutosh/frames/positive/test1.mp4/58.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/1.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/2.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/4.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/4.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/6.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/21.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/22.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/23.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/24.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/23.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/24.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/25.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/26.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/25.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/26.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/27.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/28.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/27.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/28.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/29.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/30.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/29.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/30.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/31.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/32.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/31.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/32.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/33.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/kmu cvpr/frames/positive/flame2.avi/34.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/19.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/20.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/21.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/22.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/21.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/22.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/23.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/24.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/23.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/24.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/25.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/Storyblocks/frames/positive/modern-warfare-soldier-in-action-near-window-changing-magazine-and-take-cover--SBV-346537349-preview.mp4/26.jpg']]
