# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/Tesi')

# %%
import cv2
import math
import copy
import random
import numpy as np
import pandas as pd
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from keras.models import load_model
from tensorflow.keras.utils import Sequence

import warnings
warnings.filterwarnings('ignore')

# %%
sequence_length = 4
sequence_stride = 2
batch_size      = 16

# %% [markdown]
# # Network model

# %% [markdown]
# ## Loading the pre-trained model

# %%
sn_path = 'models/urban/SN_urban_pre-trained.h5'
sn = load_model(sn_path)

sn.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 227, 227, 3  0           []
#                                 )]
#
#  conv1 (Conv2D)                 (None, 113, 113, 64  1792        ['input_1[0][0]']
#                                 )
#
#  relu_conv1 (Activation)        (None, 113, 113, 64  0           ['conv1[0][0]']
#                                 )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['relu_conv1[0][0]']
#
#  fire2/squeeze1x1 (Conv2D)      (None, 56, 56, 16)   1040        ['pool1[0][0]']
#
#  fire2/relu_squeeze1x1 (Activat  (None, 56, 56, 16)  0           ['fire2/squeeze1x1[0][0]']
#  ion)
#
#  fire2/expand1x1 (Conv2D)       (None, 56, 56, 64)   1088        ['fire2/relu_squeeze1x1[0][0]']
#
#  fire2/expand3x3 (Conv2D)       (None, 56, 56, 64)   9280        ['fire2/relu_squeeze1x1[0][0]']
#
#  fire2/relu_expand1x1 (Activati  (None, 56, 56, 64)  0           ['fire2/expand1x1[0][0]']
#  on)
#
#  fire2/relu_expand3x3 (Activati  (None, 56, 56, 64)  0           ['fire2/expand3x3[0][0]']
#  on)
#
#  fire2/concat (Concatenate)     (None, 56, 56, 128)  0           ['fire2/relu_expand1x1[0][0]',
#                                                                   'fire2/relu_expand3x3[0][0]']
#
#  fire3/squeeze1x1 (Conv2D)      (None, 56, 56, 16)   2064        ['fire2/concat[0][0]']
#
#  fire3/relu_squeeze1x1 (Activat  (None, 56, 56, 16)  0           ['fire3/squeeze1x1[0][0]']
#  ion)
#
#  fire3/expand1x1 (Conv2D)       (None, 56, 56, 64)   1088        ['fire3/relu_squeeze1x1[0][0]']
#
#  fire3/expand3x3 (Conv2D)       (None, 56, 56, 64)   9280        ['fire3/relu_squeeze1x1[0][0]']
#
#  fire3/relu_expand1x1 (Activati  (None, 56, 56, 64)  0           ['fire3/expand1x1[0][0]']
#  on)
#
#  fire3/relu_expand3x3 (Activati  (None, 56, 56, 64)  0           ['fire3/expand3x3[0][0]']
#  on)
#
#  fire3/concat (Concatenate)     (None, 56, 56, 128)  0           ['fire3/relu_expand1x1[0][0]',
#                                                                   'fire3/relu_expand3x3[0][0]']
#
#  pool3 (MaxPooling2D)           (None, 27, 27, 128)  0           ['fire3/concat[0][0]']
#
#  fire4/squeeze1x1 (Conv2D)      (None, 27, 27, 32)   4128        ['pool3[0][0]']
#
#  fire4/relu_squeeze1x1 (Activat  (None, 27, 27, 32)  0           ['fire4/squeeze1x1[0][0]']
#  ion)
#
#  fire4/expand1x1 (Conv2D)       (None, 27, 27, 128)  4224        ['fire4/relu_squeeze1x1[0][0]']
#
#  fire4/expand3x3 (Conv2D)       (None, 27, 27, 128)  36992       ['fire4/relu_squeeze1x1[0][0]']
#
#  fire4/relu_expand1x1 (Activati  (None, 27, 27, 128)  0          ['fire4/expand1x1[0][0]']
#  on)
#
#  fire4/relu_expand3x3 (Activati  (None, 27, 27, 128)  0          ['fire4/expand3x3[0][0]']
#  on)
#
#  fire4/concat (Concatenate)     (None, 27, 27, 256)  0           ['fire4/relu_expand1x1[0][0]',
#                                                                   'fire4/relu_expand3x3[0][0]']
#
#  fire5/squeeze1x1 (Conv2D)      (None, 27, 27, 32)   8224        ['fire4/concat[0][0]']
#
#  fire5/relu_squeeze1x1 (Activat  (None, 27, 27, 32)  0           ['fire5/squeeze1x1[0][0]']
#  ion)
#
#  fire5/expand1x1 (Conv2D)       (None, 27, 27, 128)  4224        ['fire5/relu_squeeze1x1[0][0]']
#
#  fire5/expand3x3 (Conv2D)       (None, 27, 27, 128)  36992       ['fire5/relu_squeeze1x1[0][0]']
#
#  fire5/relu_expand1x1 (Activati  (None, 27, 27, 128)  0          ['fire5/expand1x1[0][0]']
#  on)
#
#  fire5/relu_expand3x3 (Activati  (None, 27, 27, 128)  0          ['fire5/expand3x3[0][0]']
#  on)
#
#  fire5/concat (Concatenate)     (None, 27, 27, 256)  0           ['fire5/relu_expand1x1[0][0]',
#                                                                   'fire5/relu_expand3x3[0][0]']
#
#  pool5 (MaxPooling2D)           (None, 13, 13, 256)  0           ['fire5/concat[0][0]']
#
#  fire6/squeeze1x1 (Conv2D)      (None, 13, 13, 48)   12336       ['pool5[0][0]']
#
#  fire6/relu_squeeze1x1 (Activat  (None, 13, 13, 48)  0           ['fire6/squeeze1x1[0][0]']
#  ion)
#
#  fire6/expand1x1 (Conv2D)       (None, 13, 13, 192)  9408        ['fire6/relu_squeeze1x1[0][0]']
#
#  fire6/expand3x3 (Conv2D)       (None, 13, 13, 192)  83136       ['fire6/relu_squeeze1x1[0][0]']
#
#  fire6/relu_expand1x1 (Activati  (None, 13, 13, 192)  0          ['fire6/expand1x1[0][0]']
#  on)
#
#  fire6/relu_expand3x3 (Activati  (None, 13, 13, 192)  0          ['fire6/expand3x3[0][0]']
#  on)
#
#  fire6/concat (Concatenate)     (None, 13, 13, 384)  0           ['fire6/relu_expand1x1[0][0]',
#                                                                   'fire6/relu_expand3x3[0][0]']
#
#  fire7/squeeze1x1 (Conv2D)      (None, 13, 13, 48)   18480       ['fire6/concat[0][0]']
#
#  fire7/relu_squeeze1x1 (Activat  (None, 13, 13, 48)  0           ['fire7/squeeze1x1[0][0]']
#  ion)
#
#  fire7/expand1x1 (Conv2D)       (None, 13, 13, 192)  9408        ['fire7/relu_squeeze1x1[0][0]']
#
#  fire7/expand3x3 (Conv2D)       (None, 13, 13, 192)  83136       ['fire7/relu_squeeze1x1[0][0]']
#
#  fire7/relu_expand1x1 (Activati  (None, 13, 13, 192)  0          ['fire7/expand1x1[0][0]']
#  on)
#
#  fire7/relu_expand3x3 (Activati  (None, 13, 13, 192)  0          ['fire7/expand3x3[0][0]']
#  on)
#
#  fire7/concat (Concatenate)     (None, 13, 13, 384)  0           ['fire7/relu_expand1x1[0][0]',
#                                                                   'fire7/relu_expand3x3[0][0]']
#
#  fire8/squeeze1x1 (Conv2D)      (None, 13, 13, 64)   24640       ['fire7/concat[0][0]']
#
#  fire8/relu_squeeze1x1 (Activat  (None, 13, 13, 64)  0           ['fire8/squeeze1x1[0][0]']
#  ion)
#
#  fire8/expand1x1 (Conv2D)       (None, 13, 13, 256)  16640       ['fire8/relu_squeeze1x1[0][0]']
#
#  fire8/expand3x3 (Conv2D)       (None, 13, 13, 256)  147712      ['fire8/relu_squeeze1x1[0][0]']
#
#  fire8/relu_expand1x1 (Activati  (None, 13, 13, 256)  0          ['fire8/expand1x1[0][0]']
#  on)
#
#  fire8/relu_expand3x3 (Activati  (None, 13, 13, 256)  0          ['fire8/expand3x3[0][0]']
#  on)
#
#  fire8/concat (Concatenate)     (None, 13, 13, 512)  0           ['fire8/relu_expand1x1[0][0]',
#                                                                   'fire8/relu_expand3x3[0][0]']
#
#  fire9/squeeze1x1 (Conv2D)      (None, 13, 13, 64)   32832       ['fire8/concat[0][0]']
#
#  fire9/relu_squeeze1x1 (Activat  (None, 13, 13, 64)  0           ['fire9/squeeze1x1[0][0]']
#  ion)
#
#  fire9/expand1x1 (Conv2D)       (None, 13, 13, 256)  16640       ['fire9/relu_squeeze1x1[0][0]']
#
#  fire9/expand3x3 (Conv2D)       (None, 13, 13, 256)  147712      ['fire9/relu_squeeze1x1[0][0]']
#
#  fire9/relu_expand1x1 (Activati  (None, 13, 13, 256)  0          ['fire9/expand1x1[0][0]']
#  on)
#
#  fire9/relu_expand3x3 (Activati  (None, 13, 13, 256)  0          ['fire9/expand3x3[0][0]']
#  on)
#
#  fire9/concat (Concatenate)     (None, 13, 13, 512)  0           ['fire9/relu_expand1x1[0][0]',
#                                                                   'fire9/relu_expand3x3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['fire9/concat[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1024)         525312      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 2)            2050        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1,249,858
# Trainable params: 1,249,858
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Remove the last layers

# %%
from keras import Model

sn_nofreeze = Model(inputs=sn.input, outputs=sn.layers[-4].output)

for layer in sn_nofreeze.layers:
  layer.trainable = True

# sn_nofreeze.summary()

# %% [markdown]
# ## CNN + LSTM

# %%
from keras.layers import TimeDistributed, Input, LSTM, Dense, Dropout

input_layer = Input(shape=(sequence_length, 227, 227, 3))
mnv2_reshaped = TimeDistributed(sn_nofreeze)(input_layer)
CNNandLSTM = LSTM(100, activation='relu')(mnv2_reshaped)
dropout = Dropout(0.5)(CNNandLSTM)
output = Dense(1, activation='sigmoid')(dropout)

model = Model(inputs=input_layer, outputs=output)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 4, 227, 227, 3)]  0
#
#  time_distributed (TimeDistr  (None, 4, 512)           722496
#  ibuted)
#
#  lstm (LSTM)                 (None, 100)               245200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 967,797
# Trainable params: 967,797
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('models/urban/SN_LSTM_urban_trainable_True.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # Inference with pre-trained CNN on single test frames

# %%
path = 'csv/Test/urban/KFold_short-range/fold5'
csvs = os.listdir(path)
test_data = {'filename':[], 'Flames':[]}

for csv in csvs:
    temp = pd.read_csv(path + '/' + csv)
    for index, row in temp.iterrows():
      test_data['filename'].append(row['filename'])
      test_data['Flames'].append(row['Flames'])

test_data = pd.DataFrame(test_data)
print("Test data samples: " + str(len(test_data)) + ".\nPositive test frames: " +
      str(test_data[test_data['Flames'] == 1].count()[0]) + ".\nNegative test frames: " +
      str(test_data[test_data['Flames'] == 0].count()[0]) + ".")

# %%
# putting our test data labels in the proper format and shape desired
col = test_data['Flames']
col = list(col)

t = []
for i in col:
  t.append(str(i))

td = {'filename':[], 'Flames':[]}

for index, row in test_data.iterrows():
  td['filename'].append(row['filename'])
  td['Flames'].append(t[index])

test_data = pd.DataFrame(td)

# %%
new_test_data = {'filename':[], 'Flames':[]}

for index, row in test_data.iterrows():
  new_test_data['filename'].append('/content/drive/My Drive' + row['filename'][30:])
  new_test_data['Flames'].append(str(row['Flames']))

n_t_d = pd.DataFrame(new_test_data)

# %%
#Funzione di preprocessing
from keras.applications.imagenet_utils import preprocess_input

def preproc_function(img):
  image_t = preprocess_input(x = img, mode = 'tf')
  return image_t

# %%
import tensorflow
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard, CSVLogger, EarlyStopping

test_datagen = ImageDataGenerator(preprocessing_function = tensorflow.keras.applications.mobilenet_v2.preprocess_input)

test_generator = test_datagen.flow_from_dataframe(dataframe = n_t_d, 
                                                    x_col='filename', 
                                                    y_col='Flames', 
                                                    class_mode='binary',
                                                    target_size=(227,227),
                                                    batch_size=32,
                                                    shuffle=False)
# Out:
# Found 1965 validated image filenames belonging to 2 classes.

# %%
from keras.models import load_model

sn_path = 'models/urban/SN_urban_pre-trained.h5'
sn = load_model(sn_path)

pred = sn.predict(test_generator)
# Out:
# 62/62 [==============================] - 64s 1s/step

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_cm(y, pred):
  p = pred.argmax(-1)
  cm = confusion_matrix(y, p)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot()
  plt.title('Accuracy: %.3f' % (y==p).mean())
  plt.show()

# %%
test_lab = []
for i in list(n_t_d['Flames']):
  test_lab.append(int(i))
plot_cm(y=test_lab, pred=pred)

# %% [markdown]
# # Evaluate

# %%
class DataGenerator(Sequence):

    def __init__(self, data, batch_size, shuffle_data, aug):
        self.num_samples = len(data)
        self.data = shuffle(data) if shuffle_data else data
        self.batch_size = batch_size
        self.aug = aug        
        self.additional_targets = {[f'image{i}' for i in range(sequence_length-1)][j]:'image' for j in range(sequence_length-1)}

    def __len__(self):
        return math.ceil(len(self.data) / self.batch_size)

    def __getitem__(self, idx):
        #print('starting index: ', idx * self.batch_size)
        batch_samples = self.data[idx * self.batch_size:(idx + 1) * self.batch_size]
        X_train = []
        y_train = []
        for batch_sample in batch_samples:
            x = batch_sample[0]   # Load image (X)
            y = batch_sample[1]   # Read label (y)
            temp_data_list = []
            for img_name in x:
                try:
                    img = cv2.imread(img_name)
                    img = cv2.resize(img, (224,224))
                    temp_data_list.append(img[:,:, ::-1])
                except Exception as e:
                    print(e)
                    print('error reading file: ', img_name)
            # if self.aug:
            #     temp_data_list = self.__totransform__(temp_data_list)
            # Add example to arrays
            X_train.append(temp_data_list)
            y_train.append(y)
        # Make sure they're numpy arrays (as opposed to lists)
        X_train = np.array(X_train)
        y_train = np.array(y_train)
        return X_train, y_train

# %%
def file_generator(data_path, data_files, temporal_stride, temporal_length):
  '''
  data_files - list of csv files to be read
  '''
  for f in data_files:
    tmp_df = pd.read_csv(os.path.join(data_path, f))
    total_images = len(tmp_df)
    if total_images >= temporal_length:
      num_samples = int((total_images - temporal_length)/temporal_stride) + 1
      #print('num of samples from vid seq-{}: {}'.format(f, num_samples))
    else:
      #print('num of frames is less than temporal length; hence discarding this \
      #      file-{}'.format(f))
      continue

    samples = deque()
    labels = deque()

    for index, row in tmp_df.iterrows():
      samples.append('/content/drive/My Drive' + row['filename'][30:])
      labels.append(int(row['Flames']))
      if len(samples) == temporal_length:
        to_delete = False
        if labels.count(labels[0]) != len(labels):
          to_delete = True
        samples_c = copy.deepcopy(samples)
        for t in range(temporal_stride):
          samples.popleft()
          labels.popleft()
        if to_delete: continue
        yield samples_c, labels[0]

def load_samples(CSV_folder, temporal_stride, temporal_length):
  data_path = os.path.join('csv', CSV_folder)
  data_files = os.listdir(data_path)
  file_gen = file_generator(data_path, data_files, temporal_stride, temporal_length)
  iterator = True
  data_list = []

  while iterator:
    try:
      x, y = next(file_gen)
      x = list(x)
      data_list.append([x, y])
    except Exception as e:
      #print('Exception: ', e)
      iterator = False
      #print('end of data generator ')
  return data_list

test_data = load_samples(CSV_folder='Test/urban/KFold_short-range/fold5', 
                            temporal_stride=sequence_stride,
                            temporal_length=sequence_length)

test_gen = DataGenerator(data=test_data, batch_size=batch_size, 
                         shuffle_data=False, aug=False)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_cm(y, pred):
  p = []
  for i in pred:
    p.append(round(list(i)[0]))
  p = np.array(p)
  y = np.array(y)
  cm = confusion_matrix(y, p)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot()
  plt.title('Accuracy: %.3f' % (y==p).mean())
  plt.show()

model = load_model('models/urban/short-range/SqueezeNet/case7/case7_best_model5.h5')

test_labels = []
for test in range(len(test_data)):
  test_labels.append(test_data[test][1])

pred = model.predict(test_gen)
plot_cm(y=test_labels, pred=list(pred))
# Out:
# 78/78 [==============================] - 591s 8s/step

# %%
model.evaluate(test_gen)
# Out:
# 78/78 [==============================] - 169s 2s/step - loss: 0.3113 - accuracy: 0.8312
# [0.3112754225730896, 0.8311793208122253]

# %%
p = []
for i in pred:
  p.append(round(list(i)[0]))
p = np.array(p)
y = np.array(test_labels)

test_labels = list(y)
scores = list(p)

# %%
from keras.metrics import AUC # Approximates the Area Under the Curve of the ROC curve
from sklearn.metrics import balanced_accuracy_score

b_acc = balanced_accuracy_score(y_true=y, y_pred=p)

TP=TN=FP=FN = 0

for i in range(len(test_labels)):
    if test_labels[i] == 1 and scores[i] == 1:
        TP = TP + 1
    elif test_labels[i] == 0 and scores[i] == 0:
        TN = TN + 1
    elif test_labels[i] == 0 and scores[i] == 1:
        FP = FP + 1
    elif test_labels[i] == 1 and scores[i] == 0:
        FN = FN + 1

AR = (TP + TN)/(TP + TN + FP + FN)
Precision = TP/(TP + FP)
Recall = TP/(TP + FN)
TPR = TP/(TP + FN)
TNR = TN/(TN + FP)
FPR = FP/(FP + TN)
FNR = FN/(FN + TP)
F1score = (2 * Precision * Recall)/(Precision + Recall)
Auc = AUC()
Auc.update_state(test_labels, scores)

print("True Positives: " + str(TP) + "\nTrue Negatives: " + str(TN) + 
      "\nFalse Positives: " + str(FP) + "\nFalse Negatives: " + str(FN) +
      "\nTrue Positive rate: " + str(round(TPR, 3)) + "\nTrue negative rate: " +
      str(round(TNR, 3)) + "\nFalse Positive rate: " + str(round(FPR, 3)) +
      "\nFalse Negative rate: " + str(round(FNR, 3)) + "\nAccuracy Rate: " + 
      str(round(AR, 3)) + "\nPrecision: " + str(round(Precision, 3)) + 
      "\nRecall: " + str(round(Recall, 3)) + "\nBalanced accuracy: " + 
      str(round(b_acc, 3)) + "\nF1-Score: " + str(round(F1score, 3)) + 
      "\nArea under ROC curve: " + str(round(float(Auc.result()), 3)))
# Out:
# True Positives: 601
# True Negatives: 428
# False Positives: 88
# False Negatives: 121
# True Positive rate: 0.832
# True negative rate: 0.829
# False Positive rate: 0.171
# False Negative rate: 0.168
# Accuracy Rate: 0.831
# Precision: 0.872
# Recall: 0.832
# Balanced accuracy: 0.831
# F1-Score: 0.852
# Area under ROC curve: 0.831

# %%
from sklearn.metrics import roc_curve

def plot_roc_curve(fpr,tpr): 
  plt.plot(fpr,tpr) 
  plt.axis([0,1,0,1]) 
  plt.xlabel('False Positive Rate') 
  plt.ylabel('True Positive Rate') 
  plt.show()

p = []
for i in pred:
  p.append(round(list(i)[0]))
p = np.array(p)

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_true=np.array(test_labels), y_score=p)
plot_roc_curve(fpr_keras,tpr_keras)

# %% [markdown]
# ## Which samples are wrongly predicted?

# %%
wrong_predictions01 = []
wrong_predictions10 = []

for i in range(len(test_labels)):
    if test_data[i][1] == 0 and scores[i] == 1:
      wrong_predictions01.append(test_data[i][0])
    if test_data[i][1] == 1 and scores[i] == 0:
      wrong_predictions10.append(test_data[i][0])

# %%
all_videos = {'name':[], 'num':[]}

video_name = wrong_predictions01[0][0]
uno = video_name[56:]
revers_uno = uno[::-1]
last_slash = revers_uno.index('/') + 1
semifinal = video_name[56:-last_slash]
rev = semifinal[::-1]
penultimo = rev.index('/')
final = semifinal[-penultimo:]
temp = final
count = 0

for list_of_lists in wrong_predictions01:
  video_name = list_of_lists[0]
  uno = video_name[56:]
  revers_uno = uno[::-1]
  last_slash = revers_uno.index('/') + 1
  semifinal = video_name[56:-last_slash]
  rev = semifinal[::-1]
  penultimo = rev.index('/')
  final = semifinal[-penultimo:]
  
  if final != temp:
    all_videos['name'].append(temp)
    all_videos['num'].append(count)
    count = 0
    temp = final
  count += 1
all_videos['name'].append(temp)
all_videos['num'].append(count)

df_wrong01 = pd.DataFrame(all_videos)
df_wrong01
# Out:
#                                      name  num
# 0                       testneg04.810.avi   41
# 1                       testpos02.818.avi   34
# 2  istockphoto-1315346872-640_adpp_is.mp4    3
# 3                                 Six.mp4   10

# %%
all_videos = {'name':[], 'num':[]}

video_name = wrong_predictions10[0][0]
uno = video_name[56:]
revers_uno = uno[::-1]
last_slash = revers_uno.index('/') + 1
semifinal = video_name[56:-last_slash]
rev = semifinal[::-1]
penultimo = rev.index('/')
final = semifinal[-penultimo:]
temp = final
count = 0

for list_of_lists in wrong_predictions10:
  video_name = list_of_lists[0]
  uno = video_name[56:]
  revers_uno = uno[::-1]
  last_slash = revers_uno.index('/') + 1
  semifinal = video_name[56:-last_slash]
  rev = semifinal[::-1]
  penultimo = rev.index('/')
  final = semifinal[-penultimo:]
  
  if final != temp:
    all_videos['name'].append(temp)
    all_videos['num'].append(count)
    count = 0
    temp = final
  count += 1
all_videos['name'].append(temp)
all_videos['num'].append(count)

df_wrong10 = pd.DataFrame(all_videos)
df_wrong10
# Out:
#                                                 name  num
# 0  depositphotos_162701594-stock-video-fire-billo...   17
# 1                                         house6.mp4   14
# 2              istockphoto-501685818-640_adpp_is.mp4    2
# 3                                          fire2.mp4   41
# 4                                          test1.mp4   18
# 5                                         flame2.avi   16
# 6  masked-team-of-armed-modern-warfare-soldiers-t...    1
# 7  modern-warfare-soldier-in-action-near-window-c...   12

# %%
wrong_predictions01
# Out:
# [['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/1.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/2.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/4.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/4.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/6.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/6.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/8.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/8.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/10.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/10.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/11.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/12.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/11.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/12.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/13.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/14.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/13.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/14.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/15.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/16.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/15.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/16.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/17.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/18.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/17.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/18.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/19.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/20.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/19.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/20.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/21.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/22.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/21.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/22.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/23.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/24.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/23.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/24.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/25.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/26.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/25.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/26.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/27.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/28.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/27.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/28.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/29.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/30.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/29.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/30.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/31.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/32.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/31.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/32.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/33.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/34.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/33.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/34.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/35.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/36.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/35.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/36.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/37.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/38.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/37.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/38.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/39.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/40.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/39.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/40.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/41.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/42.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/41.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/42.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/43.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/44.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/43.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/44.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/45.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/46.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/45.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/46.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/47.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/48.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/47.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/48.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/49.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/50.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/49.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/50.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/51.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/52.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/51.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/52.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/53.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/54.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/53.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/54.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/55.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/56.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/55.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/56.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/57.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/58.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/57.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/58.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/59.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/60.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/59.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/60.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/61.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/62.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/61.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/62.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/63.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/64.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/63.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/64.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/65.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/66.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/65.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/66.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/67.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/68.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/67.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/68.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/69.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/70.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/69.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/70.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/71.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/72.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/71.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/72.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/73.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/74.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/73.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/74.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/75.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/76.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/75.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/76.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi/77.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/short-range/FIRESENSE dataset/frames/negative/testneg04.810.avi