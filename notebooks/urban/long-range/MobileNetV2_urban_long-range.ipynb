# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/Tesi')

# %%
import cv2
import math
import copy
import random
import numpy as np
import pandas as pd
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from keras.models import load_model
from tensorflow.keras.utils import Sequence

import warnings
warnings.filterwarnings('ignore')

# %%
sequence_length = 4
sequence_stride = 2
batch_size      = 16

# %% [markdown]
# # Network model

# %% [markdown]
# ## Loading the pre-trained model

# %%
mnv2_path = 'models/urban/MNV2_urban_pre-trained.h5'
mnv2 = load_model(mnv2_path)

mnv2.summary()

# %% [markdown]
# ## Remove the top layers

# %%
from keras import Model

mnv2_nofreeze = Model(inputs=mnv2.input, outputs=mnv2.layers[-4].output)

for layer in mnv2_nofreeze.layers:
  layer.trainable = True

# mnv2_nofreeze.summary()

# %% [markdown]
# ## CNN + LSTM

# %%
from keras.layers import TimeDistributed, Input, LSTM, Dense, Dropout

input_layer = Input(shape=(sequence_length, 224, 224, 3))
mnv2_reshaped = TimeDistributed(mnv2_nofreeze)(input_layer)
CNNandLSTM = LSTM(100, activation='relu')(mnv2_reshaped)
dropout = Dropout(0.5)(CNNandLSTM)
output = Dense(1, activation='sigmoid')(dropout)

model = Model(inputs=input_layer, outputs=output)
model.summary()

# %%
model.save('models/urban/MNV2_LSTM_urban_trainable_True.h5')

# %% [markdown]
# # Inference with pre-trained CNN on single test frames

# %%
path = 'csv/Test/urban/KFold_long-range/fold2'
csvs = os.listdir(path)
test_data = {'filename':[], 'Flames':[]}

for csv in csvs:
    temp = pd.read_csv(path + '/' + csv)
    for index, row in temp.iterrows():
      test_data['filename'].append(row['filename'])
      test_data['Flames'].append(row['Flames'])

test_data = pd.DataFrame(test_data)
print("Test data samples: " + str(len(test_data)) + ".\nPositive test frames: " +
      str(test_data[test_data['Flames'] == 1].count()[0]) + ".\nNegative test frames: " +
      str(test_data[test_data['Flames'] == 0].count()[0]) + ".")

# %%
# putting our test data labels in the proper format and shape desired
col = test_data['Flames']
col = list(col)

t = []
for i in col:
  t.append(str(i))

td = {'filename':[], 'Flames':[]}

for index, row in test_data.iterrows():
  td['filename'].append(row['filename'])
  td['Flames'].append(t[index])

test_data = pd.DataFrame(td)

# %%
new_test_data = {'filename':[], 'Flames':[]}

for index, row in test_data.iterrows():
  new_test_data['filename'].append('/content/drive/My Drive' + row['filename'][30:])
  new_test_data['Flames'].append(str(row['Flames']))

n_t_d = pd.DataFrame(new_test_data)

# %%
import tensorflow
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard, CSVLogger, EarlyStopping

test_datagen = ImageDataGenerator(preprocessing_function = tensorflow.keras.applications.efficientnet.preprocess_input)

test_generator = test_datagen.flow_from_dataframe(dataframe = n_t_d, 
                                                    x_col='filename', 
                                                    y_col='Flames', 
                                                    class_mode='binary',
                                                    target_size=(224,224),
                                                    batch_size=32,
                                                    shuffle=False)

# %%
from keras.models import load_model

mnv2_path = 'models/urban/MNV2_urban_pre-trained.h5'
mnv2 = load_model(mnv2_path)

pred = mnv2.predict(test_generator)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_cm(y, pred):
  p = pred.argmax(-1)
  cm = confusion_matrix(y, p)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot()
  plt.title('Accuracy: %.3f' % (y==p).mean())
  plt.show()

# %%
test_lab = []
for i in list(n_t_d['Flames']):
  test_lab.append(int(i))
plot_cm(y=test_lab, pred=pred)

# %% [markdown]
# # Evaluate

# %%
class DataGenerator(Sequence):

    def __init__(self, data, batch_size, shuffle_data, aug):
        self.num_samples = len(data)
        self.data = shuffle(data) if shuffle_data else data
        self.batch_size = batch_size
        self.aug = aug        
        self.additional_targets = {[f'image{i}' for i in range(sequence_length-1)][j]:'image' for j in range(sequence_length-1)}

    def __len__(self):
        return math.ceil(len(self.data) / self.batch_size)

    def __getitem__(self, idx):
        #print('starting index: ', idx * self.batch_size)
        batch_samples = self.data[idx * self.batch_size:(idx + 1) * self.batch_size]
        X_train = []
        y_train = []
        for batch_sample in batch_samples:
            x = batch_sample[0]   # Load image (X)
            y = batch_sample[1]   # Read label (y)
            temp_data_list = []
            for img_name in x:
                try:
                    img = cv2.imread(img_name)
                    img = cv2.resize(img, (224,224))
                    temp_data_list.append(img[:,:, ::-1])
                except Exception as e:
                    print(e)
                    print('error reading file: ', img_name)
            # if self.aug:
            #     temp_data_list = self.__totransform__(temp_data_list)
            # Add example to arrays
            X_train.append(temp_data_list)
            y_train.append(y)
        # Make sure they're numpy arrays (as opposed to lists)
        X_train = np.array(X_train)
        y_train = np.array(y_train)
        return X_train, y_train

# %%
def file_generator(data_path, data_files, temporal_stride, temporal_length):
  '''
  data_files - list of csv files to be read
  '''
  for f in data_files:
    tmp_df = pd.read_csv(os.path.join(data_path, f))
    total_images = len(tmp_df)
    if total_images >= temporal_length:
      num_samples = int((total_images - temporal_length)/temporal_stride) + 1
      #print('num of samples from vid seq-{}: {}'.format(f, num_samples))
    else:
      #print('num of frames is less than temporal length; hence discarding this \
      #      file-{}'.format(f))
      continue

    samples = deque()
    labels = deque()

    for index, row in tmp_df.iterrows():
      samples.append('/content/drive/My Drive' + row['filename'][30:])
      labels.append(int(row['Flames']))
      if len(samples) == temporal_length:
        to_delete = False
        if labels.count(labels[0]) != len(labels):
          to_delete = True
        samples_c = copy.deepcopy(samples)
        for t in range(temporal_stride):
          samples.popleft()
          labels.popleft()
        if to_delete: continue
        yield samples_c, labels[0]

def load_samples(CSV_folder, temporal_stride, temporal_length):
  data_path = os.path.join('csv', CSV_folder)
  data_files = os.listdir(data_path)
  file_gen = file_generator(data_path, data_files, temporal_stride, temporal_length)
  iterator = True
  data_list = []

  while iterator:
    try:
      x, y = next(file_gen)
      x = list(x)
      data_list.append([x, y])
    except Exception as e:
      #print('Exception: ', e)
      iterator = False
      #print('end of data generator ')
  return data_list

test_data = load_samples(CSV_folder='Test/urban/KFold_long-range/fold2', 
                            temporal_stride=sequence_stride,
                            temporal_length=sequence_length)

test_gen = DataGenerator(data=test_data, batch_size=batch_size, 
                         shuffle_data=False, aug=False)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_cm(y, pred):
  p = []
  for i in pred:
    p.append(round(list(i)[0]))
  p = np.array(p)
  y = np.array(y)
  cm = confusion_matrix(y, p)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot()
  plt.title('Accuracy: %.3f' % (y==p).mean())
  plt.show()

model = load_model('models/urban/long-range/MobileNetV2/case7/case7_best_model2.h5')

test_labels = []
for test in range(len(test_data)):
  test_labels.append(test_data[test][1])

pred = model.predict(test_gen)
plot_cm(y=test_labels, pred=list(pred))
# Out:
# 52/52 [==============================] - 453s 9s/step

# %%
model.evaluate(test_gen)
# Out:
# 52/52 [==============================] - 205s 4s/step - loss: 0.2123 - accuracy: 0.9431
# [0.212289497256279, 0.9430992603302002]

# %%
p = []
for i in pred:
  p.append(round(list(i)[0]))
p = np.array(p)
y = np.array(test_labels)

test_labels = list(y)
scores = list(p)

# %%
from keras.metrics import AUC # Approximates the Area Under the Curve of the ROC curve
from sklearn.metrics import balanced_accuracy_score

b_acc = balanced_accuracy_score(y_true=y, y_pred=p)

TP=TN=FP=FN = 0

for i in range(len(test_labels)):
    if test_labels[i] == 1 and scores[i] == 1:
        TP = TP + 1
    elif test_labels[i] == 0 and scores[i] == 0:
        TN = TN + 1
    elif test_labels[i] == 0 and scores[i] == 1:
        FP = FP + 1
    elif test_labels[i] == 1 and scores[i] == 0:
        FN = FN + 1

AR = (TP + TN)/(TP + TN + FP + FN)
Precision = TP/(TP + FP)
Recall = TP/(TP + FN)
TPR = TP/(TP + FN)
TNR = TN/(TN + FP)
FPR = FP/(FP + TN)
FNR = FN/(FN + TP)
F1score = (2 * Precision * Recall)/(Precision + Recall)
Auc = AUC()
Auc.update_state(test_labels, scores)

print("True Positives: " + str(TP) + "\nTrue Negatives: " + str(TN) + 
      "\nFalse Positives: " + str(FP) + "\nFalse Negatives: " + str(FN) +
      "\nTrue Positive rate: " + str(round(TPR, 3)) + "\nTrue negative rate: " +
      str(round(TNR, 3)) + "\nFalse Positive rate: " + str(round(FPR, 3)) +
      "\nFalse Negative rate: " + str(round(FNR, 3)) + "\nAccuracy Rate: " + 
      str(round(AR, 3)) + "\nPrecision: " + str(round(Precision, 3)) + 
      "\nRecall: " + str(round(Recall, 3)) + "\nBalanced accuracy: " + 
      str(round(b_acc, 3)) + "\nF1-Score: " + str(round(F1score, 3)) + 
      "\nArea under ROC curve: " + str(round(float(Auc.result()), 3)))
# Out:
# True Positives: 200
# True Negatives: 579
# False Positives: 8
# False Negatives: 39
# True Positive rate: 0.837
# True negative rate: 0.986
# False Positive rate: 0.014
# False Negative rate: 0.163
# Accuracy Rate: 0.943
# Precision: 0.962
# Recall: 0.837
# Balanced accuracy: 0.912
# F1-Score: 0.895
# Area under ROC curve: 0.912

# %%
from sklearn.metrics import roc_curve

def plot_roc_curve(fpr,tpr): 
  plt.plot(fpr,tpr) 
  plt.axis([0,1,0,1]) 
  plt.xlabel('False Positive Rate') 
  plt.ylabel('True Positive Rate') 
  plt.show()

p = []
for i in pred:
  p.append(round(list(i)[0]))
p = np.array(p)

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_true=np.array(test_labels), y_score=p)
plot_roc_curve(fpr_keras,tpr_keras)

# %% [markdown]
# ## Which samples are wrongly predicted?

# %%
wrong_predictions01 = []
wrong_predictions10 = []

for i in range(len(test_labels)):
    if test_data[i][1] == 0 and scores[i] == 1:
      wrong_predictions01.append(test_data[i][0])
    if test_data[i][1] == 1 and scores[i] == 0:
      wrong_predictions10.append(test_data[i][0])

# %%
all_videos = {'name':[], 'num':[]}

video_name = wrong_predictions01[0][0]
uno = video_name[55:]
revers_uno = uno[::-1]
last_slash = revers_uno.index('/') + 1
semifinal = video_name[55:-last_slash]
rev = semifinal[::-1]
penultimo = rev.index('/')
final = semifinal[-penultimo:]
temp = final
count = 0

for list_of_lists in wrong_predictions01:
  video_name = list_of_lists[0]
  uno = video_name[55:]
  revers_uno = uno[::-1]
  last_slash = revers_uno.index('/') + 1
  semifinal = video_name[55:-last_slash]
  rev = semifinal[::-1]
  penultimo = rev.index('/')
  final = semifinal[-penultimo:]
  
  if final != temp:
    all_videos['name'].append(temp)
    all_videos['num'].append(count)
    count = 0
    temp = final
  count += 1
all_videos['name'].append(temp)
all_videos['num'].append(count)

df_wrong01 = pd.DataFrame(all_videos)
df_wrong01
# Out:
#                                      name  num
# 0  istockphoto-1328393940-640_adpp_is.mp4    7
# 1  istockphoto-1423217415-640_adpp_is.mp4    1

# %%
df_wrong01['num'].sum()
# Out:
# 8

# %%
all_videos = {'name':[], 'num':[]}

video_name = wrong_predictions10[0][0]
uno = video_name[55:]
revers_uno = uno[::-1]
last_slash = revers_uno.index('/') + 1
semifinal = video_name[55:-last_slash]
rev = semifinal[::-1]
penultimo = rev.index('/')
final = semifinal[-penultimo:]
temp = final
count = 0

for list_of_lists in wrong_predictions10:
  video_name = list_of_lists[0]
  uno = video_name[55:]
  revers_uno = uno[::-1]
  last_slash = revers_uno.index('/') + 1
  semifinal = video_name[55:-last_slash]
  rev = semifinal[::-1]
  penultimo = rev.index('/')
  final = semifinal[-penultimo:]
  
  if final != temp:
    all_videos['name'].append(temp)
    all_videos['num'].append(count)
    count = 0
    temp = final
  count += 1
all_videos['name'].append(temp)
all_videos['num'].append(count)

df_wrong10 = pd.DataFrame(all_videos)
df_wrong10
# Out:
#                                             name  num
# 0                            sBehindtheFence.avi   14
# 1         istockphoto-1434212346-640_adpp_is.mp4    6
# 2          outdoor_night_20m_heptane_CCD_001.avi    2
# 3  petrochemical-plant-torch-1163768-PREVIEW.mp4    3
# 4                      Pexels Videos 2080320.mp4    5
# 5                      production ID_4961452.mp4    9

# %%
df_wrong10['num'].sum()
# Out:
# 39

# %%
wrong_predictions01
# Out:
# [['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/21.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/22.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/23.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/24.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/29.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/30.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/31.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/32.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/31.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/32.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/33.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/34.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/33.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/34.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/35.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/36.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/35.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/36.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/37.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/38.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/37.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/38.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/39.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/40.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/39.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/40.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/41.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1328393940-640_adpp_is.mp4/42.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1423217415-640_adpp_is.mp4/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1423217415-640_adpp_is.mp4/8.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1423217415-640_adpp_is.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/negative/istockphoto-1423217415-640_adpp_is.mp4/10.jpg']]

# %%
wrong_predictions10
# Out:
# [['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/85.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/86.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/87.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/88.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/87.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/88.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/89.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/90.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/95.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/96.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/97.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/98.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/97.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/98.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/99.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/100.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/99.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/100.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/101.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/102.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/106.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/107.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/108.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/109.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/108.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/109.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/110.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/111.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/110.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/111.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/112.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/113.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/112.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/113.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/114.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/115.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/114.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/115.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/116.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/117.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/116.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/117.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/118.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/119.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/118.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/119.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/120.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/121.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/120.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/121.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/122.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/123.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/122.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/123.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/124.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Bilkent dataset/frames/positive/sBehindtheFence.avi/125.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/1.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/2.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/4.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/4.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/6.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/6.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/8.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/8.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/10.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/10.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/11.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/12.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/13.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/14.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/15.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/iStock/frames/positive/istockphoto-1434212346-640_adpp_is.mp4/16.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/kmu cvpr/frames/positive/outdoor_night_20m_heptane_CCD_001.avi/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/kmu cvpr/frames/positive/outdoor_night_20m_heptane_CCD_001.avi/6.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/kmu cvpr/frames/positive/outdoor_night_20m_heptane_CCD_001.avi/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/kmu cvpr/frames/positive/outdoor_night_20m_heptane_CCD_001.avi/8.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/kmu cvpr/frames/positive/outdoor_night_20m_heptane_CCD_001.avi/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/kmu cvpr/frames/positive/outdoor_night_20m_heptane_CCD_001.avi/8.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/kmu cvpr/frames/positive/outdoor_night_20m_heptane_CCD_001.avi/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/kmu cvpr/frames/positive/outdoor_night_20m_heptane_CCD_001.avi/10.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/1.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/2.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/4.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/4.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/6.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/6.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Motion array/frames/positive/petrochemical-plant-torch-1163768-PREVIEW.mp4/8.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/1.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/2.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/4.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/4.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/6.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/8.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/10.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/10.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/11.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/12.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/17.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/18.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/19.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/Pexels Videos 2080320.mp4/20.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/1.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/2.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/4.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/3.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/4.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/6.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/5.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/6.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/8.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/7.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/8.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/10.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/9.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/10.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/11.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/12.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/11.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/12.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/13.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/14.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/15.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/16.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/17.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/18.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/17.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/18.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/19.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/20.jpg'],
#  ['/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/19.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/20.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/21.jpg',
#   '/content/drive/My Drive/Tesi/datasets/urban/long-range/Pexels/frames/positive/production ID_4961452.mp4/22.jpg']]
